# %%
#This notebook is my 1st python notebook for day 13.
#It stores basic personal details and performs simple calculations.

name="Pathu"
age=19
city="Kochi"

age_months=age*12
age_days=age*365
age_hours=age*365*24

print("Name:",name)
print("City:",city)
print("Age in months:",age_months)
print("Age in days:",age_days)
print("Age in hours:",age_hours)
# Out:
# Name: Pathu
# City: Kochi
# Age in months: 228
# Age in days: 6935
# Age in hours: 166440

# %%
#this line will cause an error
print("My age is :"+age)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 #this line will cause an error
# ----> 2 print("My age is :"+age)
#
# TypeError: can only concatenate str (not "int") to str

# %%
#error:TypeError occurs because a string and integer cannot be concatenated directly.
#solution:convert integer to string using str(age)
