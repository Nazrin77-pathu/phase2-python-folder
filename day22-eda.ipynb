# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("Mall_Customers.csv")

df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %% [markdown]
# # Dataset loaded successfully
# #Displaying first 5 rows to understand structure

# %%
df.shape
# Out:
# (200, 5)

# %% [markdown]
# # Dataset contains 200 rows and 5 columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Gender                  200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %% [markdown]
# # Columns include:CustomerID,Gender,Age,Annual Income (k$)Spending Score (1–100)

# %%
#Data cleaning

# %%
df.isnull().sum()
# Out:
# CustomerID                0
# Gender                    0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %% [markdown]
# # No missing values found.Dataset is already clean

# %%
df.groupby("Gender")["Annual Income (k$)"].mean()
# Out:
# Gender
# Female    59.250000
# Male      62.227273
# Name: Annual Income (k$), dtype: float64

# %% [markdown]
# # Comparing average income by gender

# %%
df.groupby("Gender")["Spending Score (1-100)"].mean()
df[df["Age"] > 40]
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 8             9    Male   64                  19                       3
# 10           11    Male   67                  19                      14
# 12           13  Female   58                  20                      15
# 18           19    Male   52                  23                      29
# 22           23  Female   46                  25                       5
# ..          ...     ...  ...                 ...                     ...
# 184         185  Female   41                  99                      39
# 186         187  Female   54                 101                      24
# 188         189  Female   41                 103                      17
# 194         195  Female   47                 120                      16
# 196         197  Female   45                 126                      28
#
# [78 rows x 5 columns]

# %% [markdown]
# # Filtering customers older than 40

# %%
# Scatter plot

# %%
plt.scatter(df["Annual Income (k$)"], df["Spending Score (1-100)"])
plt.title("Income vs Spending Score")
plt.xlabel("Annual Income")
plt.ylabel("Spending Score")
plt.show()

# %%
# histogram:

# %%
plt.hist(df["Age"])
plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# # Observation 1
#
# #Customers with higher income do not always have higher spending scores.

# %% [markdown]
# # Observation 2
#
# #Most customers are concentrated in the age range of 20 to 40 years.

# %% [markdown]
# # Observation 3
#
# #Male and female customers have similar average annual incomes.

# %% [markdown]
# # Observation 4
#
# #Some customers with moderate income show very high spending behavior.

# %% [markdown]
# # Observation 5
#
# #There are fewer older customers compared to younger customers in the dataset.
