# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\LENOVO\OneDrive\Desktop\internship\day12-dataset.csv")
df.columns
# Out:
# Index(['Row ID', 'Ship Date', 'Order ID', 'Customer ID', 'Ship Mode',
#        'Order Date', 'Segment', 'Country', 'City', 'Customer Name',
#        'Postal Code', 'Region', 'Sales', 'State', 'Product ID', 'Quantity',
#        'Discount', 'Sub-Category', 'Product Name', 'Category', 'Profit'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Ship Date      9994 non-null   object
#  2   Order ID       9994 non-null   object
#  3   Customer ID    9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Order Date     9994 non-null   object
#  6   Segment        9994 non-null   object
#  7   Country        9994 non-null   object
#  8   City           9994 non-null   object
#  9   Customer Name  9994 non-null   object
#  10  Postal Code    9994 non-null   int64
#  11  Region         9994 non-null   object
#  12  Sales          9994 non-null   object
#  13  State          9994 non-null   object
#  14  Product ID     9994 non-null   object
#  15  Quantity       9994 non-null   int64
#  16  Discount       9994 non-null   float64
# ...

# %%
df[["Sales", "Profit"]]
# Out:
#          Sales      Profit
# 0      ₹ 77.88      ₹ 3.89
# 1       ₹ 6.63      ₹ 1.79
# 2       ₹ 5.88      ₹ 1.71
# 3       ₹ 5.46      ₹ 1.53
# 4      ₹ 73.20     ₹ 21.23
# ...        ...         ...
# 9989    ₹ 4.84    12.09 -₹
# 9990    ₹ 8.62   2.5872 -₹
# 9991      ₹ 14      6.3 -₹
# 9992   ₹ 25.13   6.9102 -₹
# 9993  ₹ 528.43  143.431 -₹
#
# [9994 rows x 2 columns]

# %%
# This displays two important numeric columns for comparison.

# %%
df["Sales"] = df["Sales"].astype(str).str.replace("₹", "").str.replace(",", "").str.strip()
df["Profit"] = df["Profit"].astype(str).str.replace("₹", "").str.replace(",", "").str.strip()
df["Sales"] = pd.to_numeric(df["Sales"], errors="coerce")
df["Profit"] = pd.to_numeric(df["Profit"], errors="coerce")

# %%
df[df["Sales"] > df["Sales"].mean()]
# Out:
#       Row ID  Ship Date        Order ID Customer ID       Ship Mode  \
# 10      2065  11-Apr-14  CA-2014-106439    GG-14650  Standard Class
# 14      2944  24-Nov-17  CA-2017-126242    MC-18100  Standard Class
# 23      3845  31-Oct-14  CA-2014-101931    TS-21370     First Class
# 30      4487  11-Aug-16  CA-2016-109365    XP-21865  Standard Class
# 31      4561  12-Sep-15  CA-2015-118871    HM-14860    Second Class
# ...      ...        ...             ...         ...             ...
# 9981    9577  28-May-15  CA-2015-143147    PS-18760    Second Class
# 9984    9593  08-Jan-16  US-2016-105452    BF-11005  Standard Class
# 9986    9625  30-Jun-17  CA-2017-137449    ME-17725     First Class
# 9987    9626  30-Jun-17  CA-2017-137449    ME-17725     First Class
# 9993    9920  19-Mar-16  CA-2016-149272    MY-18295  Standard Class
#
#      Order Date      Segment        Country         City    Customer Name  \
# 10    31-Oct-14    Corporate  United States  Los Angeles     Greg Guthrie
# ...

# %%
# This shows rows where Sales are higher than average.

# %%
df.sort_values(by="Sales", ascending=False)
# Out:
#       Row ID  Ship Date        Order ID Customer ID       Ship Mode  \
# 9079    2698  23-Mar-14  CA-2014-145317    SM-20320  Standard Class
# 1404    6827  10-Sep-16  CA-2016-118689    TC-20980  Standard Class
# 1418    8154  25-Mar-17  CA-2017-140151    RB-19360     First Class
# 4815    2624  24-Oct-17  CA-2017-127180    TA-21385     First Class
# 1374    4191  22-Nov-17  CA-2017-166709    HL-15040  Standard Class
# ...      ...        ...             ...         ...             ...
# 8942    2107  26-Sep-14  US-2014-152723    HG-14965        Same Day
# 8793    4712  31-Mar-14  CA-2014-112403    JO-15280        Same Day
# 8901    8659  25-Jun-16  CA-2016-168361    KB-16600  Standard Class
# 9056    9293  03-Feb-17  CA-2017-124114    RS-19765        Same Day
# 9742    4102  23-Jun-17  US-2017-102288    ZC-21910  Standard Class
#
#      Order Date      Segment        Country           City     Customer Name  \
# ...

# %%
# This sorts the dataset from highest to lowest Sales.

# %%
df[(df["Sales"] > 500) & (df["Profit"] > 100)]
# Out:
#       Row ID  Ship Date        Order ID Customer ID       Ship Mode  \
# 46      6160  12-Sep-16  CA-2016-161025    GM-14440  Standard Class
# 57      8055  09-Apr-15  CA-2015-121188    CB-12025  Standard Class
# 72      1626  24-Dec-15  CA-2015-157084    JG-15160  Standard Class
# 92      8587  18-Jul-17  CA-2017-162015    KB-16240  Standard Class
# 112     2405  10-Nov-17  CA-2017-108574    MG-18145  Standard Class
# ...      ...        ...             ...         ...             ...
# 9539    9406  17-Mar-14  CA-2014-152618    RB-19465     First Class
# 9689    4813  19-Nov-16  CA-2016-121370    EB-14110    Second Class
# 9702    6426  27-May-16  CA-2016-143714    CC-12370  Standard Class
# 9718    8124  15-Dec-14  CA-2014-138128    FP-14320  Standard Class
# 9726    8800  05-Oct-14  CA-2014-116666    KT-16480     First Class
#
#      Order Date      Segment        Country          City       Customer Name  \
# ...

# %%
# This filters rows where both Sales and Profit are high.
